# %% [markdown]
# <a href="https://colab.research.google.com/github/mons-trev/Generative_AI_research/blob/main/test/huggingface_stable_diffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 필요한 라이브러리 설치
# !pip install torch torchvision torchaudio
# !pip install transformers
# !pip install diffusers[torch] # hugging face diffusers 라이브러리
# !pip install accelerate # 분산 학습 라이브러리
# !pip install scipy

# Git 저장소 복제
# !git clone https://github.com/Ewha-DoInJi/stable-diffusion.git
# %cd stable-diffusion
# Out:
# ...
# fatal: destination path 'stable-diffusion' already exists and is not an empty directory.
# /content/stable-diffusion

# %%
# 모델 다운로드 (예: Hugging Face의 stabilityai/stable-diffusion-2-1-base)
from diffusers import StableDiffusionPipeline
import torch

model_id = "stabilityai/stable-diffusion-2-1-base"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
from diffusers import StableDiffusionPipeline
import torch  # torch 임포트 추가
import matplotlib.pyplot as plt

# 텍스트 프롬프트로부터 이미지 생성
prompt = "A beautiful landscape painting of mountains at sunset"
with torch.autocast("cuda"):
    image = pipe(prompt).images[0]

# 이미지 표시
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,

# %%
# 텍스트 프롬프트로부터 이미지 생성
prompt = "college student who major in computer science engineering drinking energe drink"
with torch.autocast("cuda"):
    image = pipe(prompt).images[0]

# 이미지 표시
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# 텍스트 프롬프트로부터 이미지 생성
prompt = "happy family eating dinner at restaurant"
with torch.autocast("cuda"):
    image = pipe(prompt).images[0]

# 이미지 표시
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# 텍스트 프롬프트로부터 이미지 생성
prompt = "love"
with torch.autocast("cuda"):
    image = pipe(prompt).images[0]

# 이미지 표시
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# 텍스트 프롬프트로부터 이미지 생성
prompt = "새벽 4시에 못 자고 코딩하는 나"
with torch.autocast("cuda"):
    image = pipe(prompt).images[0]

# 이미지 표시
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# !pip install pytorch_lightning
# !pip install omegaconf



# 클론해온 stable-diffusion 디렉토리로 이동
# %cd /content/stable-diffusion

# main.py 파일 실행
# !python main.py
# Out:
# ...
# /content/stable-diffusion
# Traceback (most recent call last):
#   File "/content/stable-diffusion/main.py", line 17, in <module>
#     from pytorch_lightning.utilities.distributed import rank_zero_only
# ModuleNotFoundError: No module named 'pytorch_lightning.utilities.distributed'
